# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
get_ipython().magic('matplotlib notebook')

# %%
whi = pd.read_csv('Happiness_Cantril_Ladder.csv')

# %%
whi = whi.rename(columns={'World Happiness Report 2016 (Cantril Ladder (0=worst; 10=best))': 'WHIindex'})
whi.head()
# Out:
#         Entity Code  Year  WHIindex
# 0  Afghanistan  AFG  2008  3.723590
# 1  Afghanistan  AFG  2009  4.401778
# 2  Afghanistan  AFG  2010  4.758381
# 3  Afghanistan  AFG  2011  3.831719
# 4  Afghanistan  AFG  2012  3.782938

# %%
whi2016 = whi[whi['Year']==2016]
whi2015 = whi[whi['Year']==2015]
whi2014 = whi[whi['Year']==2014]
whi2013 = whi[whi['Year']==2013]
whi2012 = whi[whi['Year']==2012]
whi2011 = whi[whi['Year']==2011]
whi2010 = whi[whi['Year']==2010]
whi2009 = whi[whi['Year']==2009]
whi2008 = whi[whi['Year']==2008]

# %%
whi2008.head()
# Out:
#          Entity Code  Year  WHIindex
# 0   Afghanistan  AFG  2008  3.723590
# 29    Argentina  ARG  2008  5.961034
# 40      Armenia  ARM  2008  4.651972
# 51    Australia  AUS  2008  7.253757
# 60      Austria  AUT  2008  7.180954

# %%
entity = whi2008[['Entity']]
entity.set_index('Entity', inplace=True)

# %%
entity
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
worldaverageindex=whi
worldaverageindex.head()
# Out:
#         Entity Code  Year  WHIindex
# 0  Afghanistan  AFG  2008  3.723590
# 1  Afghanistan  AFG  2009  4.401778
# 2  Afghanistan  AFG  2010  4.758381
# 3  Afghanistan  AFG  2011  3.831719
# 4  Afghanistan  AFG  2012  3.782938

# %%
worldaverageindex = worldaverageindex.groupby(['Year'], as_index=False).mean()

# %%
worldaverageindex
# Out:
#     Year  WHIindex
# 0   2005  6.446164
# 1   2006  5.196935
# 2   2007  5.418291
# 3   2008  5.418554
# 4   2009  5.457640
# 5   2010  5.496782
# 6   2011  5.424088
# 7   2012  5.443751
# 8   2013  5.394568
# 9   2014  5.389023
# 10  2015  5.404037
# 11  2016  5.399626

# %%
worldaverageindex = worldaverageindex.drop([0,1,2])

# %%
worldaverageindex = worldaverageindex.reset_index()

# %%
worldaverageindex.drop(['index'], axis = 1, inplace = True)

# %%
worldaverageindex
# Out:
#    Year  WHIindex
# 0  2008  5.418554
# 1  2009  5.457640
# 2  2010  5.496782
# 3  2011  5.424088
# 4  2012  5.443751
# 5  2013  5.394568
# 6  2014  5.389023
# 7  2015  5.404037
# 8  2016  5.399626

# %%
years = worldaverageindex[['Year']]
index = worldaverageindex[['WHIindex']]

# %%
years
# Out:
#    Year
# 0  2008
# 1  2009
# 2  2010
# 3  2011
# 4  2012
# 5  2013
# 6  2014
# 7  2015
# 8  2016

# %%
index
# Out:
#    WHIindex
# 0  5.418554
# 1  5.457640
# 2  5.496782
# 3  5.424088
# 4  5.443751
# 5  5.394568
# 6  5.389023
# 7  5.404037
# 8  5.399626

# %%
plt.style.use('bmh')
plt.plot(years,index,'-o', c='navy', alpha=0.4)
plt.xlabel('Years')
plt.ylabel('World Happiness Index')
plt.title('Happiness Index Variation (2008-2016)')
plt.legend(['Average of Year'])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', '_classic_test']

# %%
literacy = pd.read_csv('literacy.csv')

# %%
literacy = literacy.transpose()

# %%
literacy
# Out:
#            0         1         2         3      4    5    6      7    \
# 2008       NaN       NaN       NaN  95.93864    NaN  NaN  NaN    NaN
# 2009       NaN       NaN       NaN       NaN    NaN  NaN  NaN    NaN
# 2010  96.82264       NaN       NaN       NaN    NaN  NaN  NaN    NaN
# 2011       NaN  31.74112       NaN  96.84530    NaN  NaN  NaN    NaN
# 2012       NaN       NaN       NaN  97.24697    NaN  NaN  NaN    NaN
# 2013       NaN       NaN       NaN       NaN    NaN  NaN  NaN    NaN
# 2014       NaN       NaN  66.03011       NaN    NaN  NaN  NaN    NaN
# 2015       NaN       NaN       NaN       NaN  100.0  NaN  NaN  98.09
# 2016       NaN       NaN       NaN       NaN  100.0  NaN  NaN    NaN
# 2017       NaN       NaN       NaN       NaN    NaN  NaN  NaN    NaN
#
#            8    9      ...           255  256       257       258  259  260  \
# 2008       NaN  NaN    ...           NaN  NaN  83.83223       NaN  NaN  NaN
# ...

# %%
literacy = literacy[[264]]

# %%
literacy = literacy.drop(['2017'])

# %%
literacy
# Out:
#             264
# 2008  80.453839
# 2009  84.252752
# 2010  83.225059
# 2011  86.685214
# 2012  81.793922
# 2013  83.963313
# 2014  82.788916
# 2015  87.495857
# 2016  86.135870

# %%
literacy = literacy.rename(columns={264: 'Literacy Average Index'})

# %%
literacy
# Out:
#       Literacy Average Index
# 2008               80.453839
# 2009               84.252752
# 2010               83.225059
# 2011               86.685214
# 2012               81.793922
# 2013               83.963313
# 2014               82.788916
# 2015               87.495857
# 2016               86.135870

# %%
literacyindex = literacy['Literacy Average Index']

# %%
literacyindex = literacyindex/100

# %%
literacyindex
# Out:
# 2008    0.804538
# 2009    0.842528
# 2010    0.832251
# 2011    0.866852
# 2012    0.817939
# 2013    0.839633
# 2014    0.827889
# 2015    0.874959
# 2016    0.861359
# Name: Literacy Average Index, dtype: float64

# %%
plt.plot(years,literacyindex,'-o')
